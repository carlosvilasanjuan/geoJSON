# %% [markdown]
# # geoJSON project

# %% [markdown]
# ## 0.  Scope of the project:
#
#
# - Given the preferences of the staff of a company we are asked to make an informed recomendation on the most suitable place to locate their in order to help the company grow.
#
#
# - We are also mandated to take into acount at least three of the employees preferences.
#
# #### Staff requirements:

# %%
import pandas as pd
pd.read_csv('staff_sumary.csv')
# Out:
#     Unnamed: 0               pos  \
# 0           13  Account Managers
# 1            3               CEO
# 2           12    Data Engineers
# 3            0         Designers
# 4            1        Developers
# 5            2        Executives
# 6            4   Maintenance guy
# 7           11   UI/UX Engineers
# 8            5         other_req
# 9            6         other_req
# 10           7         other_req
# 11           8         other_req
# 12           9         other_req
# 13          10         other_req
#
#                                                   req   num
# 0                            No specific requirements  20.0
# 1   \nThe CEO is Vegan\nIf you want to make the ma...   1.0
# 2                            No specific requirements  15.0
# 3   \nDesigners like to go to design talks and sha...  20.0
# 4   \nDevelopers like to be near successful tech s...  15.0
# 5                   \nExecutives like Starbucks A LOT  10.0
# ...
